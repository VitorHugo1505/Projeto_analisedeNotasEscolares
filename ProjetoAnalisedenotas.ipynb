# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorHugo1505/Projeto_analisedeNotasEscolares/blob/main/ProjetoAnalisedenotas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
Base_Dados = pd.read_csv('StudentsPerformance.csv')

# %%
Base_Dados.shape
# Out:
# (1000, 8)

# %%
Base_Dados.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#verificar os campos nulos
Nulos = Base_Dados.isnull()
plt.figure( figsize= (16,5 ) )
plt.title('Campos Nulos')
sns.heatmap( Nulos, cbar=False);

# %%
#campos unicos
Base_Dados.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
#verificar a porcetagem em cada coluna
Base_Dados['gender'].value_counts(normalize=True) * 100

#51% da base é feminina e 48% é masculina
# Out:
# gender
# female    51.8
# male      48.2
# Name: proportion, dtype: float64

# %%
Base_Dados['race/ethnicity'].value_counts(normalize=True) * 100
# Out:
# race/ethnicity
# group C    31.9
# group D    26.2
# group B    19.0
# group E    14.0
# group A     8.9
# Name: proportion, dtype: float64

# %%
Base_Dados['parental level of education'].value_counts(normalize=True) * 100
# Out:
# parental level of education
# some college          22.6
# associate's degree    22.2
# high school           19.6
# some high school      17.9
# bachelor's degree     11.8
# master's degree        5.9
# Name: proportion, dtype: float64

# %%
Base_Dados['lunch'].value_counts(normalize=True) * 100
# Out:
# lunch
# standard        64.5
# free/reduced    35.5
# Name: proportion, dtype: float64

# %%
Base_Dados['test preparation course'].value_counts(normalize=True) * 100
# Out:
# test preparation course
# none         64.2
# completed    35.8
# Name: proportion, dtype: float64

# %%
sns.boxplot(data= Base_Dados, x= 'math score', y = 'gender')
# Out:
# <Axes: xlabel='math score', ylabel='gender'>
